# %%
import pandas as pd
df = pd.read_csv("practrice.csv")

# %%
df.shape
# Out:
# (1190, 12)

# %%
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
df.sample(6)
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 749    42    1                4           140          226
# 1064   56    1                4           132          184
# 878    60    1                4           130          206
# 551    55    1                4           172          260
# 592    58    1                4           100          213
# 318    56    1                4           140            0
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 749                     0            0             178                0
# 1064                    0            2             105                1
# 878                     0            2             132                1
# 551                     0            0              73                0
# 592                     0            1             110                0
# 318                     1            0             121                1
#
#       oldpeak  ST slope  target
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1190 non-null   int64
#  1   sex                  1190 non-null   int64
#  2   chest pain type      1190 non-null   int64
#  3   resting bp s         1190 non-null   int64
#  4   cholesterol          1190 non-null   int64
#  5   fasting blood sugar  1190 non-null   int64
#  6   resting ecg          1190 non-null   int64
#  7   max heart rate       1190 non-null   int64
#  8   exercise angina      1190 non-null   int64
#  9   oldpeak              1190 non-null   float64
#  10  ST slope             1190 non-null   int64
#  11  target               1190 non-null   int64
# dtypes: float64(1), int64(11)
# memory usage: 111.7 KB

# %% [markdown]
# ## are there missing values?

# %%
df.isnull().sum()
# Out:
# age                    0
# sex                    0
# chest pain type        0
# resting bp s           0
# cholesterol            0
# fasting blood sugar    0
# resting ecg            0
# max heart rate         0
# exercise angina        0
# oldpeak                0
# ST slope               0
# target                 0
# dtype: int64

# %% [markdown]
# ## How does the data look mathematically?

# %%
df.describe()
# Out:
#                age          sex  chest pain type  resting bp s  cholesterol  \
# count  1190.000000  1190.000000      1190.000000   1190.000000  1190.000000
# mean     53.720168     0.763866         3.232773    132.153782   210.363866
# std       9.358203     0.424884         0.935480     18.368823   101.420489
# min      28.000000     0.000000         1.000000      0.000000     0.000000
# 25%      47.000000     1.000000         3.000000    120.000000   188.000000
# 50%      54.000000     1.000000         4.000000    130.000000   229.000000
# 75%      60.000000     1.000000         4.000000    140.000000   269.750000
# max      77.000000     1.000000         4.000000    200.000000   603.000000
#
#        fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# count          1190.000000  1190.000000     1190.000000      1190.000000
# mean              0.213445     0.698319      139.732773         0.387395
# ...

# %% [markdown]
# ## Are there duplicate values?

# %%
df.duplicated().sum()
# Out:
# 272

# %% [markdown]
# ## How does correlation between columns?

# %%
df.corr()
# Out:
#                           age       sex  chest pain type  resting bp s  \
# age                  1.000000  0.015096         0.149055      0.257692
# sex                  0.015096  1.000000         0.138405     -0.006443
# chest pain type      0.149055  0.138405         1.000000      0.009466
# resting bp s         0.257692 -0.006443         0.009466      1.000000
# cholesterol         -0.046472 -0.208441        -0.109396      0.099037
# fasting blood sugar  0.178923  0.110961         0.076492      0.088235
# resting ecg          0.194595 -0.022225         0.035705      0.095860
# max heart rate      -0.368676 -0.181837        -0.337491     -0.101357
# exercise angina      0.188095  0.194380         0.403428      0.142435
# oldpeak              0.245093  0.096390         0.224106      0.176111
# ST slope             0.237749  0.127913         0.276949      0.089384
# target               0.262029  0.311267         0.460127      0.121415
#
# ...

# %%
df.corr()['target']
# Out:
# age                    0.262029
# sex                    0.311267
# chest pain type        0.460127
# resting bp s           0.121415
# cholesterol           -0.198366
# fasting blood sugar    0.216695
# resting ecg            0.073059
# max heart rate        -0.413278
# exercise angina        0.481467
# oldpeak                0.398385
# ST slope               0.505608
# target                 1.000000
# Name: target, dtype: float64

# %% [markdown]
# suggests that chest pain type is very strongly correlated with target

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %% [markdown]
# #### Univariate analysis

# %% [markdown]
# genarally two types : categorical data and numerical data

# %% [markdown]
# ## 1. Categorical Data

# %% [markdown]
# #### a. Countplot

# %%
df['target'].value_counts()
# Out:
# target
# 1    629
# 0    561
# Name: count, dtype: int64

# %%
import seaborn as sns
df['target'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='target'>

# %%
df['sex'].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='sex'>

# %% [markdown]
# ## b. Piechart

# %%
import matplotlib
df['target'].value_counts().plot(kind = 'pie',autopct = "%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df['chest pain type'].value_counts().plot(kind = 'pie',autopct = "%.2f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Numerical Data

# %% [markdown]
# ### a. Histogram

# %%
import matplotlib.pyplot as plt
plt.hist(df['age'],bins = 20)
# Out:
# (array([  6.,   7.,  25.,  19.,  51.,  59.,  85.,  54.,  97.,  94., 107.,
#         144., 105., 128.,  68.,  71.,  29.,  23.,   9.,   9.]),
#  array([28.  , 30.45, 32.9 , 35.35, 37.8 , 40.25, 42.7 , 45.15, 47.6 ,
#         50.05, 52.5 , 54.95, 57.4 , 59.85, 62.3 , 64.75, 67.2 , 69.65,
#         72.1 , 74.55, 77.  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ### b.Displot(Probability Density function)

# %%
sns.distplot(df['age'])
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_8248\3234920688.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])
# C:\Users\soumy\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# #### KDE : Kernel Density Function

# %%
sns.kdeplot(df['age'])
# Out:
# C:\Users\soumy\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# ### c. Boxplot(used for 5 number summary shows outlier and percentile of noisy data)

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['age', 'sex', 'chest pain type', 'resting bp s', 'cholesterol',
#        'fasting blood sugar', 'resting ecg', 'max heart rate',
#        'exercise angina', 'oldpeak', 'ST slope', 'target'],
#       dtype='object')

# %%
df['age'].min()
# Out:
# 28

# %%
df['age'].max()
# Out:
# 77

# %%
df['age'].mean()
# Out:
# 53.72016806722689

# %% [markdown]
# ## finding Skewness of data

# %%
df['age'].skew()
# Out:
# -0.19211127980140955

# %% [markdown]
# # Bivariate Analysis

# %%
df.columns
# Out:
# Index(['age', 'sex', 'chest pain type', 'resting bp s', 'cholesterol',
#        'fasting blood sugar', 'resting ecg', 'max heart rate',
#        'exercise angina', 'oldpeak', 'ST slope', 'target'],
#       dtype='object')

# %%
tips = sns.load_dataset('tips')
tips.sample(5)
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 118       12.43  1.8  Female     No  Thur   Lunch     2
# 149        7.51  2.0    Male     No  Thur   Lunch     2
# 39        31.27  5.0    Male     No   Sat  Dinner     3
# 217       11.59  1.5    Male    Yes   Sat  Dinner     2
# 138       16.00  2.0    Male    Yes  Thur   Lunch     2

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### 1.Scatterplot (Numerical-Numerical)

# %%
tips.head(4)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2

# %%
sns.scatterplot(x='total_bill', y='tip', hue = 'sex',style = 'smoker', size = 'size',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 2. Barplot

# %%
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
sns.barplot(x = 'chest pain type',y = 'resting bp s',hue = 'sex',data = df)
# Out:
# <Axes: xlabel='chest pain type', ylabel='resting bp s'>

# %% [markdown]
# ### 3. Boxplot(Numerical-Categorical)

# %%
sns.boxplot(x = 'sex', y = 'age', hue = 'chest pain type', data = df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# ### 4. Distplot

# %%
sns.distplot(df[df['target'] == 0]['age'],hist = False)
sns.distplot(df[df['target'] == 1]['age'],hist = False)
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_8248\3221840054.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['target'] == 0]['age'],hist = False)
# C:\Users\soumy\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\soumy\AppData\Local\Temp\ipykernel_8248\3221840054.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %% [markdown]
# ## 5. Heat map (Categorical-Categorical)

# %%
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
pd.crosstab(df['resting ecg'],df['ST slope'])
# Out:
# ST slope     0    1    2   3
# resting ecg
# 0            1  330  316  37
# 1            0   66  100  15
# 2            0  130  166  29

# %%
sns.heatmap(pd.crosstab(df['resting ecg'],df['ST slope']))
# Out:
# <Axes: xlabel='ST slope', ylabel='resting ecg'>

# %%
df.groupby('ST slope').mean()['target']*100
# Out:
# ST slope
# 0    100.000000
# 1     20.912548
# 2     78.865979
# 3     72.839506
# Name: target, dtype: float64

# %%
(df.groupby('ST slope').mean()['target']*100).plot(kind = 'bar')
# Out:
# <Axes: xlabel='ST slope'>

# %%
df.groupby('sex').mean()['target']*100
# Out:
# sex
# 0    24.911032
# 1    61.496150
# Name: target, dtype: float64

# %% [markdown]
# ## 6. Cluster map (Categorical-Categorical)

# %%
df.head(3)
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0

# %%
pd.crosstab(df['fasting blood sugar'],df['chest pain type'])
# Out:
# chest pain type       1    2    3    4
# fasting blood sugar
# 0                    48  192  225  471
# 1                    18   24   58  154

# %%
sns.clustermap(pd.crosstab(df['fasting blood sugar'],df['chest pain type']))

# %% [markdown]
# ### 7. Pairplot

# %%
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
sns.pairplot(iris,hue = 'species')
plt.show()
# Out:
# C:\Users\soumy\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\soumy\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\soumy\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
#sns.pairplot(df)

# %% [markdown]
# ### 8. Lineplot ( Numerical - Numerical) { used for time dependent}

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.lineplot(x='year', y='passengers', data=flights)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Passengers')
plt.title('Number of Passengers Over the Years')
# Out:
# C:\Users\soumy\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\soumy\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Number of Passengers Over the Years')

# %%
flights.pivot_table(values = 'passengers', index = 'month',columns = 'year')
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_8248\4161353645.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights.pivot_table(values = 'passengers', index = 'month',columns = 'year')
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# ...

# %%
sns.heatmap(flights.pivot_table(values = 'passengers', index = 'month',columns = 'year'))
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_8248\3271618095.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flights.pivot_table(values = 'passengers', index = 'month',columns = 'year'))
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(flights.pivot_table(values = 'passengers', index = 'month',columns = 'year'))
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_8248\1648376670.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.clustermap(flights.pivot_table(values = 'passengers', index = 'month',columns = 'year'))

# %% [markdown]
# # Pandas Profiler

# %%
df.head(3)
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0

# %%
#!pip install pandas-profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Example DataFrame 'df'
# df = pd.DataFrame({
#     'column1': [1, 2, 3, ...],
#     'column2': ['A', 'B', 'C', ...],
#     ...
# })

# Generate the profile report
Prof = ProfileReport(df)

# Save the report to an HTML file
Prof.to_file(output_file='output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
